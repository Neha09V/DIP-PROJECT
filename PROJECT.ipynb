# %% [markdown]
# <a href="https://colab.research.google.com/github/Neha09V/DIP-PROJECT/blob/main/PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Apr 26 10:16:12 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              8W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
# Start training from a pretrained *.pt model
# !yolo detect train data=african-wildlife.yaml model=yolov8s.pt epochs=30 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 261MB/s]
# Ultralytics 8.3.116 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # pretrained YOLO11n model

# %%
results = model("/content/datasets/african-wildlife/test/images/1 (128).jpg", conf=0.1, save=True)
# Out:
# image 1/1 /content/datasets/african-wildlife/test/images/1 (128).jpg: 416x640 1 buffalo, 53.1ms
# Speed: 2.3ms preprocess, 53.1ms inference, 127.7ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict2

# %%
from IPython.display import Image, display

display(Image(filename='/content/runs/detect/predict/1 (121).jpg'))
